# %%
import pandas as pd
import numpy as np

# %%
# load 600 statements date dataset
# label: 0 is False. 1 is True.
# pre_cutoff: if True, then the date is before the model training cutoff time

df = pd.read_table('../data/600_statements.tsv', delimiter='\t')

df.head()
# Out:
#    id  pre_cutoff            date  label        region       source  \
# 0   1        True  30 August 2021      1  ASIA-PACIFIC  China Daily
# 1   2        True    28 July 2021      1  ASIA-PACIFIC  China Daily
# 2   3        True    25 June 2021      1  ASIA-PACIFIC  China Daily
# 3   4        True     20 May 2021      1  ASIA-PACIFIC  China Daily
# 4   5        True   15 April 2021      1  ASIA-PACIFIC  China Daily
#
#   original_language                                          statement  \
# 0           English  China has 56 ethnic groups. Besides the Han, w...
# 1           English  Weightlifter Shi Zhiyong of China won gold in ...
# 2           English  On the evening of June 22, 2021, Shanghai held...
# 3           English  China's health minister Ma Xiaowei said during...
# 4           English  A sandstorm hit Hohhot, Inner Mongolia on Apri...
#
#                                                 link
# 0  https://www.chinadaily.com.cn/a/202108/30/WS61...
# ...
